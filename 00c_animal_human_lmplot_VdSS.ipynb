# %%
import pandas as pd

# %%
import numpy as np

# %%
animal = pd.read_csv("../data/animal_smiles_r_v3.csv")
human_lombardo = pd.read_csv("../data/human_smiles_r_v3.csv")

# %%
animal = animal[animal["smiles_r"]!="Cannot_do"].reset_index(drop=True)
human_lombardo = human_lombardo[human_lombardo["smiles_r"]!="Cannot_do"].reset_index(drop=True)

# %%
human_lombardo = human_lombardo.rename(columns={"human VDss (L/kg)": "human_VDss_L_kg"})
human_lombardo = human_lombardo.rename(columns={"fraction unbound \nin plasma (fu)": "human_fup"})
human_lombardo = human_lombardo.rename(columns={"human CL (mL/min/kg)": "human_CL_mL_min_kg"})
human_lombardo = human_lombardo.rename(columns={"MRT (h)": "human_mrt"})
human_lombardo = human_lombardo.rename(columns={"terminal  t1/2 (h)": "human_thalf"})
human_lombardo
# Out:
#                                                smiles_r  human_VDss_L_kg  \
# 0     C#CCC(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=O)NC(CCC(...            1.015
# 1         C#CCCCC(=O)c1cc(C(C)(C)C)c([O-])c(C(C)(C)C)c1           12.000
# 2     C#CCN(Cc1cc2c(=O)nc(C)[n-]c2cc1C)c1ccc(C(=O)NC...            0.530
# 3                             C#CC[NH+](C)C(C)Cc1ccccc1            1.900
# 4     C#C[C@@]1(O)[C@@H](CO)O[C@H](n2ccc(N)nc2=O)[C@...            1.100
# ...                                                 ...              ...
# 1278                    c1cc2c(c(N3CC[NH2+]CC3)c1)OCCO2            3.600
# 1279                   c1ccc(C2([NH+]3CCCCC3)CCCCC2)cc1            6.900
# 1280              c1ccc(C2(c3ccccc3)CC2C2=[NH+]CCN2)cc1            4.100
# 1281                c1ccc(CN(CC2=[NH+]CCN2)c2ccccc2)cc1            3.900
# 1282                     c1ccc2c(c1)OCC(C1=[NH+]CCN1)O2            3.300
#
#       human_CL_mL_min_kg  human_fup  human_mrt  human_thalf      MW   HBA  \
# ...

# %%
animal
# Out:
#                                              CHEMISTRY  \
# 0                                Fc1c[nH]c(=O)[nH]c1=O
# 1                            [nH]1cnc(=S)c(c12)[nH]cn2
# 2    CO[C@@H]1[C@H](NC)C[C@@H](O2)n(c3c4n5[C@]12C)c...
# 3    C1OC(=O)[C@](O)(CC)c(c12)cc3n(c2=O)Cc4c3nc5c(c...
# 4     OC[C@@H]1C=C[C@@H](C1)n(cn2)c(c23)nc(N)nc3NC4CC4
# ..                                                 ...
# 366  OC[C@@H](O)[C@@H](O)[C@H]1[C@H](NC(=O)C)[C@H](...
# 367  [N-]=[N+]=N[C@H]1C[C@@H](O[C@@H]1CO)n2cc(C)c(=...
# 368                   OP(=O)(O)C(O)(P(=O)(O)O)Cn1ccnc1
# 369     O=C1OC[C@@H](N1)Cc(cc2)cc(c23)c(c[nH]3)CCN(C)C
# 370      Cc1ccc(cc1)-c(n2)c(CC(=O)N(C)C)n(c23)cc(C)cc3
#
#                        NAME  human_CL_mL_min_kg  rat_CL_mL_min_kg  \
# 0            5-Fluorouracil                26.0              33.0
# 1          6-Mercaptopurine                15.0               NaN
# 2    7-Hydroxystaurosporine                 0.0              65.0
# ...

# %%
human_lombardo.columns
# Out:
# Index(['smiles_r', 'human_VDss_L_kg', 'human_CL_mL_min_kg', 'human_fup',
#        'human_mrt', 'human_thalf', 'MW', 'HBA', 'HBD', 'TPSA_NO',
#        'RotBondCount', 'MoKa.LogP', 'MoKa.LogD7.4',
#        'molecular_weight_smiles_r'],
#       dtype='object')

# %%
#human = pd.concat([human_1, human_2]).reset_index(drop=True)
#We will use lombardo data only so we can compare everything at one go
#human_lombardo = human_lombardo.rename(columns={"human CL (mL/min/kg)": "human_VDss_L_kg"})
human_lombardo = human_lombardo[["smiles_r","human_VDss_L_kg"]].dropna(subset= ["human_VDss_L_kg"]).reset_index(drop=True)
human_lombardo
# Out:
#                                                smiles_r  human_VDss_L_kg
# 0     C#CCC(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=O)NC(CCC(...            1.015
# 1         C#CCCCC(=O)c1cc(C(C)(C)C)c([O-])c(C(C)(C)C)c1           12.000
# 2     C#CCN(Cc1cc2c(=O)nc(C)[n-]c2cc1C)c1ccc(C(=O)NC...            0.530
# 3                             C#CC[NH+](C)C(C)Cc1ccccc1            1.900
# 4     C#C[C@@]1(O)[C@@H](CO)O[C@H](n2ccc(N)nc2=O)[C@...            1.100
# ...                                                 ...              ...
# 1244                    c1cc2c(c(N3CC[NH2+]CC3)c1)OCCO2            3.600
# 1245                   c1ccc(C2([NH+]3CCCCC3)CCCCC2)cc1            6.900
# 1246              c1ccc(C2(c3ccccc3)CC2C2=[NH+]CCN2)cc1            4.100
# 1247                c1ccc(CN(CC2=[NH+]CCN2)c2ccccc2)cc1            3.900
# 1248                     c1ccc2c(c1)OCC(C1=[NH+]CCN1)O2            3.300
#
# [1249 rows x 2 columns]

# %%
human_lombardo = human_lombardo.groupby('smiles_r').median().reset_index()
#human = human.rename(columns={"human_VDss_L_kg": "VDss_L_kg"})
#human["organism"] = "human"
human_lombardo["log_human_VDss_L_kg"] =np.log10(human_lombardo["human_VDss_L_kg"])
human_lombardo
# Out:
#                                                smiles_r  human_VDss_L_kg  \
# 0     C#CCC(Cc1cnc2nc(N)nc(N)c2n1)c1ccc(C(=O)NC(CCC(...            1.015
# 1         C#CCCCC(=O)c1cc(C(C)(C)C)c([O-])c(C(C)(C)C)c1           12.000
# 2     C#CCN(Cc1cc2c(=O)nc(C)[n-]c2cc1C)c1ccc(C(=O)NC...            0.530
# 3                             C#CC[NH+](C)C(C)Cc1ccccc1            1.900
# 4     C#C[C@@]1(O)[C@@H](CO)O[C@H](n2ccc(N)nc2=O)[C@...            1.100
# ...                                                 ...              ...
# 1244                    c1cc2c(c(N3CC[NH2+]CC3)c1)OCCO2            3.600
# 1245                   c1ccc(C2([NH+]3CCCCC3)CCCCC2)cc1            6.900
# 1246              c1ccc(C2(c3ccccc3)CC2C2=[NH+]CCN2)cc1            4.100
# 1247                c1ccc(CN(CC2=[NH+]CCN2)c2ccccc2)cc1            3.900
# 1248                     c1ccc2c(c1)OCC(C1=[NH+]CCN1)O2            3.300
#
#       log_human_VDss_L_kg
# 0                0.006466
# 1                1.079181
# ...

# %%
rat = animal[["smiles_r", "rat_VDss_L_kg" ]].dropna(subset= ["rat_VDss_L_kg"])
dog = animal[["smiles_r", "dog_VDss_L_kg" ]].dropna(subset= ["dog_VDss_L_kg"])
monkey = animal[["smiles_r", "monkey_VDss_L_kg" ]].dropna(subset= ["monkey_VDss_L_kg"])

# %%
#rat = rat.rename(columns={"rat_VDss_L_kg": "VDss_L_kg"})
#rat["organism"] = "rat"
rat["log_rat_VDss_L_kg"] =np.log10(rat["rat_VDss_L_kg"])
rat
# Out:
#                                               smiles_r  rat_VDss_L_kg  \
# 0                              O=c1[n-]cc(F)c(=O)[n-]1           0.25
# 2    C[NH2+][C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3c...          16.70
# 3    CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(N)cccc...           5.00
# 5                 CC[NH+](CC)CCNC(=O)c1ccc(NC(C)=O)cc1           2.90
# 6                                CC(=O)Nc1ccc([O-])cc1           0.92
# ..                                                 ...            ...
# 365           CCN(C(C)=O)c1cccc(-c2ccnc3c(C#N)cnn23)c1           1.72
# 366  CC(=O)N[C@H]1[C@H]([C@H](O)[C@H](O)CO)OC(C(=O)...           0.80
# 367  Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...           0.86
# 369      C[NH+](C)CCc1c[nH]c2ccc(C[C@H]3COC(=O)N3)cc12           3.53
# 370        Cc1ccc(-c2nc3ccc(C)cn3c2CC(=O)[NH+](C)C)cc1           1.05
#
#      log_rat_VDss_L_kg
# 0            -0.602060
# 2             1.222716
# 3             0.698970
# 5             0.462398
# ...

# %%
#dog = dog.rename(columns={"dog_VDss_L_kg": "VDss_L_kg"})
#dog["organism"] = "dog"
dog["log_dog_VDss_L_kg"] =np.log10(dog["dog_VDss_L_kg"])
dog
# Out:
#                                               smiles_r  dog_VDss_L_kg  \
# 2    C[NH2+][C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3c...           6.09
# 5                 CC[NH+](CC)CCNC(=O)c1ccc(NC(C)=O)cc1           1.90
# 6                                CC(=O)Nc1ccc([O-])cc1           0.58
# 9                  [NH3+]C(C(=O)[O-])[C@@H]1CC(Cl)=NO1           0.58
# 10   CC1=[NH+]C(=O)[C@](CC[NH+](C(C)C)C(C)C)(c2cccc...           1.30
# ..                                                 ...            ...
# 361         CC(c1ncncc1F)[C@](O)(Cn1cncn1)c1ccc(F)cc1F           0.88
# 362                        O=C(CCCCCCC(O)=NO)Nc1ccccc1           0.60
# 363           CC(=O)CC(c1ccccc1)c1c([O-])c2ccccc2oc1=O           0.28
# 367  Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(...           1.00
# 368       O=P([O-])([O-])C(O)(Cn1ccnc1)P(=O)([O-])[O-]           0.28
#
#      log_dog_VDss_L_kg
# 2             0.784617
# 5             0.278754
# 6            -0.236572
# 9            -0.236572
# ...

# %%
#monkey = monkey.rename(columns={"monkey_VDss_L_kg": "VDss_L_kg"})
#monkey["organism"] = "monkey"
monkey["log_monkey_VDss_L_kg"] =np.log10(monkey["monkey_VDss_L_kg"])
monkey
# Out:
#                                               smiles_r  monkey_VDss_L_kg  \
# 1                                S=c1nc[n-]c2nc[n-]c12              0.90
# 9                  [NH3+]C(C(=O)[O-])[C@@H]1CC(Cl)=NO1              0.61
# 10   CC1=[NH+]C(=O)[C@](CC[NH+](C(C)C)C(C)C)(c2cccc...              1.60
# 11                        Nc1nc(=O)c2ncn(COCCO)c2[n-]1              0.90
# 12                   Nc1ncnc2c1ncn2CCOCP(=O)([O-])[O-]              0.81
# ..                                                 ...               ...
# 357                       CCCCCCCCCCCCCCCCCCCC(=O)[O-]              0.25
# 358               COc1ccc(C(C[NH+](C)C)C2(O)CCCCC2)cc1              3.50
# 359  COc1ccc(CC[NH+](C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C...              5.35
# 360  N#C[C@@H]1CCC[NH+]1C(=O)C[NH2+]C12CC3CC(CC(O)(...              0.70
# 364                Nc1ccn([C@H]2CC[C@@H](CO)O2)c(=O)n1              0.98
#
#      log_monkey_VDss_L_kg
# 1               -0.045757
# 9               -0.214670
# ...

# %%
data = pd.merge(rat, dog, on="smiles_r", how='outer')
data = pd.merge(data, human_lombardo, on="smiles_r", how='outer')
data = pd.merge(data, monkey, on="smiles_r", how='outer')

#data["log_VDss_L_kg"] =np.log10(data["VDss_L_kg"])
#data = data.set_index("InChICode_standardised")
data
# Out:
#                                                smiles_r  rat_VDss_L_kg  \
# 0                               O=c1[n-]cc(F)c(=O)[n-]1           0.25
# 1     C[NH2+][C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3c...          16.70
# 2     CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(N)cccc...           5.00
# 3                  CC[NH+](CC)CCNC(=O)c1ccc(NC(C)=O)cc1           2.90
# 4                                 CC(=O)Nc1ccc([O-])cc1           0.92
# ...                                                 ...            ...
# 1315                    c1cc2c(c(N3CC[NH2+]CC3)c1)OCCO2            NaN
# 1316              c1ccc(C2(c3ccccc3)CC2C2=[NH+]CCN2)cc1            NaN
# 1317                c1ccc(CN(CC2=[NH+]CCN2)c2ccccc2)cc1            NaN
# 1318                              S=c1nc[n-]c2nc[n-]c12            NaN
# 1319  CC(C)=CC[NH+]1CC[C@@]2(C)c3cc([O-])ccc3C[C@@H]...            NaN
#
#       log_rat_VDss_L_kg  dog_VDss_L_kg  log_dog_VDss_L_kg  human_VDss_L_kg  \
# ...

# %%
import seaborn as sns
import numpy as np
from scipy import stats
import scipy as st

# %%
st.__version__
# Out:
# '1.8.0'

# %%
from sklearn.linear_model import LinearRegression

# %%
sns.set(rc={'figure.figsize':(11.7,8.27), 'figure.dpi':300})

# %%
#Rat vs Human

sns.set_context("talk")
sns.set_style('white')
x = pd.merge(rat, human_lombardo)["log_rat_VDss_L_kg"].values.reshape((-1, 1))
print(len(x))
y = pd.merge(rat, human_lombardo)["log_human_VDss_L_kg"].values
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)


sns.jointplot(x="log_rat_VDss_L_kg", y="log_human_VDss_L_kg", 
               data=data[["smiles_r", "log_rat_VDss_L_kg","log_human_VDss_L_kg"]].dropna(how='any'),
                kind="reg", height=8)
# Out:
# 250
# coefficient of determination: 0.5402816166889166

# %%
#dog vs Human

sns.set_context("talk")
sns.set_style('white')

x = pd.merge(dog, human_lombardo)["log_dog_VDss_L_kg"].values.reshape((-1, 1))
print(len(x))
y = pd.merge(dog, human_lombardo)["log_human_VDss_L_kg"].values
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)


sns.jointplot(x="log_dog_VDss_L_kg", y="log_human_VDss_L_kg", 
               data=data[["smiles_r", "log_dog_VDss_L_kg","log_human_VDss_L_kg"]].dropna(how='any'),
                kind="reg", height=8)
# Out:
# 205
# coefficient of determination: 0.6018396062165101

# %%
import matplotlib.pyplot as plt
#monkey vs Human

sns.set_context("talk")
sns.set_style('white')

x = pd.merge(monkey, human_lombardo)["log_monkey_VDss_L_kg"].values.reshape((-1, 1))
print(len(x))
y = pd.merge(monkey, human_lombardo)["log_human_VDss_L_kg"].values
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)

sns.jointplot(x="log_monkey_VDss_L_kg", y="log_human_VDss_L_kg", 
               data=data[["smiles_r", "log_monkey_VDss_L_kg","log_human_VDss_L_kg"]].dropna(how='any'),
                kind="reg", height=8)

plt.ylim(-2, 2)
plt.ylim(-2, 2)
plt.show()
# Out:
# 91
# coefficient of determination: 0.7423596269308538

# %%
#Rat vs Human resampled
df = pd.merge(rat, human_lombardo).sample(91)

x = df["log_rat_VDss_L_kg"].values.reshape((-1, 1))
print(len(x))
y = df["log_human_VDss_L_kg"].values
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)


sns.jointplot(x="log_rat_VDss_L_kg", y="log_human_VDss_L_kg", 
               data=df,
                kind="reg")
plt.ylim(-2, 2)
plt.ylim(-2, 2)
plt.show()
# Out:
# 91
# coefficient of determination: 0.5726432949448526

# %%
#dog vs Human resampled
df = pd.merge(dog, human_lombardo).sample(91)

x = df["log_dog_VDss_L_kg"].values.reshape((-1, 1))
print(len(x))
y = df["log_human_VDss_L_kg"].values
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)



sns.jointplot(x="log_dog_VDss_L_kg", y="log_human_VDss_L_kg", 
               data=df,
                kind="reg")
plt.ylim(-2, 2)
plt.ylim(-2, 2)
plt.show()
# Out:
# 91
# coefficient of determination: 0.4919573231691481

# %%
data_all = data.dropna(how='any')
data_all.reset_index(drop=True, inplace=True)
data_all
# Out:
#                                              smiles_r  rat_VDss_L_kg  \
# 0                 [NH3+]C(C(=O)[O-])[C@@H]1CC(Cl)=NO1           0.74
# 1   CC1=[NH+]C(=O)[C@](CC[NH+](C(C)C)C(C)C)(c2cccc...           4.20
# 2                   Nc1ncnc2c1ncn2CCOCP(=O)([O-])[O-]           1.60
# 3   CCC(=O)N(c1ccccc1)C1(COC)CC[NH+](CCn2nnn(CC)c2...           0.54
# 4   C[NH+](C)CCc1c[nH]c2ccc(CS(=O)(=O)[NH+]3CCCC3)...           2.70
# ..                                                ...            ...
# 71      C#CCCCC(=O)c1cc(C(C)(C)C)c([O-])c(C(C)(C)C)c1           7.90
# 72  CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(C[NH+]...           3.08
# 73          COc1cc(NCc2ccc3nc(N)nc(N)c3c2C)cc(OC)c1OC           9.20
# 74               COc1ccc(C(C[NH+](C)C)C2(O)CCCCC2)cc1           6.60
# 75  COc1ccc(CC[NH+](C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C...           2.15
#
#     log_rat_VDss_L_kg  dog_VDss_L_kg  log_dog_VDss_L_kg  human_VDss_L_kg  \
# ...
